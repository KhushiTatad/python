# %%
s = "hello world"
print(s.capitalize())
# Out:
# Hello world

# %%
s = "Python"
print(s.center(20, '*'))
# Out:
# *******Python*******

# %%
s = "HELLO"
print(s.casefold())
# Out:
# hello

# %%
s = "banana"
print(s.count("a"))
# Out:
# 3

# %%
s = "hello.py"
print(s.endswith(".py"))
# Out:
# True

# %%
s = "H\te\tl\tl\to"
print(s.expandtabs(4))
# Out:
# H   e   l   l   o

# %%
s = "hello"
print(s.encode())
# Out:
# b'hello'

# %%
s = "hello world"
print(s.find("world"))
# Out:
# 6

# %%
name = "Jagdeep"
print("Hello {}".format(name))
# Out:
# Hello Jagdeep

# %%
s = "hello"
print(s.index("e"))
# Out:
# 1

# %%
s = "abc123"
print(s.isalnum())
# Out:
# True

# %%
s = "abc"
print(s.isalpha())
# Out:
# True

# %%
s = "123"
print(s.isdecimal())
# Out:
# True

# %%
s = "123"
print(s.isdigit())
# Out:
# True

# %%
s = "variable_name"
print(s.isidentifier())
# Out:
# True

# %%
s = "hello"
print(s.islower())
# Out:
# True

# %%
s = "123"
print(s.isnumeric())
# Out:
# True

# %%
s = "Hello\n"
print(s.isprintable())
# Out:
# False

# %%
s = "   "
print(s.isspace())
# Out:
# True

# %%
s = "Hello World"
print(s.istitle())
# Out:
# True

# %%
s = "HELLO"
print(s.isupper())
# Out:
# True
